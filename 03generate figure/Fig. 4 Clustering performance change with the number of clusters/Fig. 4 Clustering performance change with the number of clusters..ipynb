# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif']=['Times New Roman']
fig = plt.figure(figsize=(6, 4), dpi=600)
Scores = [0.5287,0.57307,0.509759,0.52364,0.50409,0.41856,0.41703,0.40904,0.40113,0.40044,0.39888,
         0.39270,0.391788,0.38918,0.38517,0.38548,0.38137] 
X = range(2,19)  
plt.xlabel('$k$')  
plt.ylabel('Silhouette Coefficient')  
plt.plot(X,Scores,'o-') 
plt.show()
